# %% [markdown]
# # Hypothesis 3 Visualizations - Range
# ## Is there a correlation between battery range and car registrations by model year?

# %%
# Dependencies
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Read in the CSV file
df = pd.read_csv("../data/clean_data/range_cleaned_vehicle_data.csv")
print(df.info())
df.head(1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86489 entries, 0 to 86488
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VIN (1-10)             86489 non-null  object
#  1   County                 86489 non-null  object
#  2   City                   86489 non-null  object
#  3   State                  86489 non-null  object
#  4   Postal Code            86489 non-null  int64
#  5   Model Year             86489 non-null  int64
#  6   Make                   86489 non-null  object
#  7   Model                  86489 non-null  object
#  8   Electric Vehicle Type  86489 non-null  object
#  9   Electric Range         86489 non-null  int64
#  10  Latitude               86489 non-null  float64
#  11  Longitude              86489 non-null  float64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 7.9+ MB
# None
#    VIN (1-10) County     City State  Postal Code  Model Year  Make Model  \
# 0  WAUTPBFF4H   King  Seattle    WA        98126        2017  AUDI    A3
#
#                     Electric Vehicle Type  Electric Range  Latitude  \
# 0  Plug-in Hybrid Electric Vehicle (PHEV)              16  47.54468
#
#     Longitude
# 0 -122.374105

# %%
df.head()
# Out:
#    VIN (1-10)    County     City State  Postal Code  Model Year   Make  \
# 0  WAUTPBFF4H      King  Seattle    WA        98126        2017   AUDI
# 1  WAUUPBFF2J  Thurston  Olympia    WA        98502        2018   AUDI
# 2  5YJSA1E22H  Thurston    Lacey    WA        98516        2017  TESLA
# 3  1C4JJXP62M  Thurston   Tenino    WA        98589        2021   JEEP
# 4  5YJ3E1EC9L    Yakima   Yakima    WA        98902        2020  TESLA
#
#       Model                   Electric Vehicle Type  Electric Range  \
# 0        A3  Plug-in Hybrid Electric Vehicle (PHEV)              16
# 1        A3  Plug-in Hybrid Electric Vehicle (PHEV)              16
# 2   MODEL S          Battery Electric Vehicle (BEV)             210
# 3  WRANGLER  Plug-in Hybrid Electric Vehicle (PHEV)              25
# 4   MODEL 3          Battery Electric Vehicle (BEV)             308
#
#     Latitude   Longitude
# 0  47.544680 -122.374105
# 1  47.059252 -122.943445
# 2  47.083975 -122.780830
# 3  46.856085 -122.854030
# 4  46.597394 -120.524012

# %%
df.describe()
# Out:
#         Postal Code    Model Year  Electric Range      Latitude     Longitude
# count  86489.000000  86489.000000    86489.000000  86489.000000  86489.000000
# mean   98284.147186   2018.491901      121.018673     47.453075   -122.066806
# std      315.486311      3.099707       99.165399      0.640970      1.096151
# min    98001.000000   1997.000000        6.000000     45.583590   -124.614078
# 25%    98057.000000   2017.000000       32.000000     47.323449   -122.451530
# 50%    98155.000000   2018.000000       83.000000     47.601800   -122.300312
# 75%    98391.000000   2020.000000      215.000000     47.718625   -122.151665
# max    99403.000000   2024.000000      337.000000     48.992052   -117.059519

# %%
color_df = [10, 10, 10, 10, 10]
labels = ['#6B9250', '#F2EBDE','#022200', '#D6CFEE', "#E7E900"]

# Create a pie chart
plt.figure(figsize=(10, 6))
plt.pie(color_df, labels=labels, startangle=90, colors=['#6B9250', '#F2EBDE','#022200', '#D6CFEE', "#E7E900"])
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle

# Add a white circle to create the donut effect
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.title('Color Palette')
plt.show()

# %%
# Step 1: Get the data
# Create the plot
plt.figure(figsize=(10,6))
sns.countplot(x='Electric Vehicle Type', hue='Electric Vehicle Type', data=df, palette=['#E7E900' ,'#D6CFEE'])

# Customizations
plt.title("Hybrid vs Battery Electric Registrations", fontsize=16, fontweight="bold")
plt.ylim(0, 50000)
plt.ylabel('Registrations')

plt.grid(color="#022200", axis="y", linestyle="--", alpha=0.25)


# Save/Show plot
plt.tight_layout()
plt.show()

# %%
mask = df["Electric Vehicle Type"] == "Battery Electric Vehicle (BEV)"

# Now we can create the new dataframe out of the mask with the rest_index function
bev_df = df.loc[mask].reset_index(drop=True)

# %%
bev_df.head()
# Out:
#    VIN (1-10)     County               City State  Postal Code  Model Year  \
# 0  5YJSA1E22H   Thurston              Lacey    WA        98516        2017
# 1  5YJ3E1EC9L     Yakima             Yakima    WA        98902        2020
# 2  5YJ3E1EB5L  Snohomish  Mountlake Terrace    WA        98043        2020
# 3  1G1FW6S03J  Snohomish            Bothell    WA        98021        2018
# 4  5YJSA1S22F       King            Seattle    WA        98121        2015
#
#         Make    Model           Electric Vehicle Type  Electric Range  \
# 0      TESLA  MODEL S  Battery Electric Vehicle (BEV)             210
# 1      TESLA  MODEL 3  Battery Electric Vehicle (BEV)             308
# 2      TESLA  MODEL 3  Battery Electric Vehicle (BEV)             322
# 3  CHEVROLET  BOLT EV  Battery Electric Vehicle (BEV)             238
# 4      TESLA  MODEL S  Battery Electric Vehicle (BEV)             208
#
#     Latitude   Longitude
# 0  47.083975 -122.780830
# 1  46.597394 -120.524012
# 2  47.784160 -122.308420
# 3  47.797727 -122.210730
# 4  47.615460 -122.344125

# %%
bev_df.describe()
# Out:
#         Postal Code    Model Year  Electric Range      Latitude     Longitude
# count  47139.000000  47139.000000    47139.000000  47139.000000  47139.000000
# mean   98257.978744   2017.511784      196.332697     47.488779   -122.104738
# std      299.532744      2.352457       73.306226      0.618844      0.990999
# min    98001.000000   1997.000000       29.000000     45.583590   -124.614078
# 25%    98052.000000   2016.000000      149.000000     47.383359   -122.422003
# 50%    98122.000000   2018.000000      215.000000     47.619252   -122.299430
# 75%    98368.000000   2019.000000      238.000000     47.740354   -122.151665
# max    99403.000000   2021.000000      337.000000     48.992052   -117.059519

# %%
mask = df["Electric Vehicle Type"] == "Plug-in Hybrid Electric Vehicle (PHEV)"

# Now we can create the new dataframe out of the mask with the rest_index function
hybrid_df = df.loc[mask].reset_index(drop=True)	
hybrid_df.head()
# Out:
#    VIN (1-10)    County     City State  Postal Code  Model Year       Make  \
# 0  WAUTPBFF4H      King  Seattle    WA        98126        2017       AUDI
# 1  WAUUPBFF2J  Thurston  Olympia    WA        98502        2018       AUDI
# 2  1C4JJXP62M  Thurston   Tenino    WA        98589        2021       JEEP
# 3  1C4JJXP66P  Thurston  Olympia    WA        98501        2023       JEEP
# 4  1G1RA6S53H    Kitsap  Keyport    WA        98345        2017  CHEVROLET
#
#       Model                   Electric Vehicle Type  Electric Range  \
# 0        A3  Plug-in Hybrid Electric Vehicle (PHEV)              16
# 1        A3  Plug-in Hybrid Electric Vehicle (PHEV)              16
# 2  WRANGLER  Plug-in Hybrid Electric Vehicle (PHEV)              25
# 3  WRANGLER  Plug-in Hybrid Electric Vehicle (PHEV)              21
# 4      VOLT  Plug-in Hybrid Electric Vehicle (PHEV)              53
#
#     Latitude   Longitude
# 0  47.544680 -122.374105
# 1  47.059252 -122.943445
# 2  46.856085 -122.854030
# 3  47.043535 -122.896920
# 4  47.702126 -122.625012

# %% [markdown]
# ## Violin Plot of BEVs and PHEVs by Range

# %%
# Create the plot
plt.figure(figsize=(10,6))
sns.violinplot(y=bev_df['Electric Range'], color='#D6CFEE', alpha=1, label='Battery Electric')
sns.violinplot(y=hybrid_df['Electric Range'], color='#E7E900', alpha=0.3, label='Hybrid')

# Customizations
plt.title("Violin Plot of BEV and PHEV Registrations by Range", fontsize=16, fontweight="bold")
plt.xlabel("Registrations", fontsize=12, fontstyle="italic")
plt.ylabel("Range (miles)", fontsize=12, fontstyle="italic")

plt.grid(color="#022200", axis="y", linestyle="--", alpha=0.1)

# Save/Show plot
plt.tight_layout()
plt.savefig("images/Violin_Plot_of_BEVs_and_PHEVs_by_Range.png")
plt.show()

# %% [markdown]
# ## Violin Plot of Hybrids by Range

# %%
# Create the plot
plt.figure(figsize=(10,6))
sns.violinplot(y=hybrid_df['Electric Range'], color='#E7E900', alpha=0.3, label='Hybrid')

# Customizations
plt.title("Violin Plot of Hybrid Registrations by Range", fontsize=16, fontweight="bold")
plt.xlabel("Registrations", fontsize=12, fontstyle="italic")
plt.ylabel("Range (miles)", fontsize=12, fontstyle="italic")

plt.grid(color="#022200", axis="y", linestyle="--", alpha=0.1)

# Save/Show plot
plt.tight_layout()
plt.savefig("images/Violin_Plot_of_Hybrids_by_Range.png")
plt.show()

# %% [markdown]
# ## Violin Plot of BEVs by Range

# %%
# Create the plot
plt.figure(figsize=(10,6))
sns.violinplot(y=bev_df['Electric Range'], color='#D6CFEE', alpha=1, label='Battery Electric')

# Customizations
plt.title("Violin Plot of BEV Registrations by Range", fontsize=16, fontweight="bold")
plt.xlabel("Registrations", fontsize=12, fontstyle="italic")
plt.ylabel("Range (miles)", fontsize=12, fontstyle="italic")

plt.grid(color="#022200", axis="y", linestyle="--", alpha=0.1)

# Save/Show plot
plt.tight_layout()
plt.savefig("images/Violin_Plot_of_BEVs_by_Range.png")
plt.show()
